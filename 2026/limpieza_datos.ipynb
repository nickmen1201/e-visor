# %% [markdown]
# ## Bloque 0 — Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %% [markdown]
# ## Bloque 1 — Carga

# %%
from pathlib import Path

# Cambiar según el formato de los archivos fuente: 'csv' o 'xlsx'
FORMAT = 'xlsx'

COL_MAP = {
    'Fecha y Hora': 'time_index_colombia',
    'ID Entidad':   'entity_id',
}

if FORMAT == 'csv':
    files = sorted(Path('.').glob('*.csv'))
    def load(f):
        return pd.read_csv(f, sep=';', low_memory=False)

elif FORMAT == 'xlsx':
    files = sorted(Path('.').glob('*.xlsx'))
    def load(f):
        return pd.read_excel(f)

print(f'{len(files)} archivos encontrados:')
for f in files:
    print(' ', f.name)

partes = []
for f in files:
    chunk = load(f)
    chunk.rename(columns=COL_MAP, inplace=True)
    partes.append(chunk)

df = pd.concat(partes, join='outer', ignore_index=True)

# Avisar si algún archivo tiene columnas distintas al resto
col_sets = [set(p.columns) for p in partes]
extra = set.union(*col_sets) - set.intersection(*col_sets)
if extra:
    print('Columnas inconsistentes entre archivos:', extra)

print(f'Shape combinado: {df.shape}')
df.head()
# Out:
# 9 archivos encontrados:
#   etsmartmeter_2026-03-12_17-47-37.xlsx
#   etsmartmeter_2026-03-12_17-49-36_parte_2.xlsx
#   etsmartmeter_2026-03-12_17-51-33_parte_3.xlsx
#   etsmartmeter_2026-03-12_17-53-27_parte_4.xlsx
#   etsmartmeter_2026-03-12_17-55-22_parte_5.xlsx
#   etsmartmeter_2026-03-12_17-57-15_parte_6.xlsx
#   etsmartmeter_2026-03-12_17-59-20_parte_7.xlsx
#   indicadores_diarios.xlsx
#   kpis_diarios.xlsx
# Columnas inconsistentes entre archivos: {'reactivepower2', 'KPI05_CO2_tCO2e', 'totalpowerfactor', 'activeenergyexportday', 'i3angle', 'HU_horas', 'powerfactor3', 'relativethdcurrent', 'powerfactor2', 'activeenergyimportday', 'Tipo Entidad', 'activepower1', 'KPI10_desbalance_pct', 'harmonicsi2', 'v1', 'LF', 'i1angle', 'KPI03_hora_pico', 'KPI09_f4_pct', 'fiware_servicepath', 'f2_CV', 'CO2_tCO2e', 'KPI11_fp', 'harmonicsv3', 'v2angle', 'reactiveenergyimport', 'i2angle', 'v3', 'i3', 'i1', 'activeenergyexport', 'reactiveenergyexport', 'harmonicsv1', 'reactiveenergyexportday', 'activeenergyimport', 'activepower', 'reactivepower1', 'KPI08_LF', 'thd_v_pct', 'powerfactor1', 'activepower3', 'i2', 'relativethdpower', 'clock', 'reactiveenergyimportday', 'instanceid', 'desbalance_pct', 'time_index_colombia', 'v3angle', 'v2', 'in', 'f1', '__original_ngsi_entity__', 'f4', 'PAR', 'v1angle', 'reactivepower', 'fp_promedio', 'KPI03_pico_kw', 'reactivepower3', 'KPI12_thd_v_pct', 'activepower2', 'fecha', 'harmonicsi1', 'relativethdvoltage', 'Frecuencia (Hz)', 'harmonicsi3', 'f3', 'harmonicsv2'}
# Shape combinado: (640061, 70)
#                 entity_id Tipo Entidad time_index_colombia fiware_servicepath  \
# 0   SmartMeter_SM_B10_ARQ   SmartMeter 2026-02-10 00:01:09                  /
# 1  SmartMeter_SM_B12_DERE   SmartMeter 2026-02-10 00:01:09                  /
# 2  SmartMeter_SM_B17_POLI   SmartMeter 2026-02-10 00:01:09                  /
# 3  SmartMeter_SM_B18_PARQ   SmartMeter 2026-02-10 00:01:09                  /
# 4   SmartMeter_SM_B3_RECT   SmartMeter 2026-02-10 00:01:09                  /
#
#   __original_ngsi_entity__                                        instanceid  \
# 0                      NaN  urn:ngsi-ld:9e0a87a2-c3b8-451a-a089-bd062e1049b1
# 1                      NaN  urn:ngsi-ld:dd9a6997-e202-4ab5-bd5b-df8b2f0021aa
# 2                      NaN  urn:ngsi-ld:a5a29398-6f6b-49f3-aacf-4e5f350a3668
# 3                      NaN  urn:ngsi-ld:d27fd9f9-134c-41a1-bed6-9374790b7646
# 4                      NaN  urn:ngsi-ld:87fc332e-5e30-4801-9cd3-273ce77e3b69
#
#        v1      v2      v3    i1  ...  fp_promedio  thd_v_pct  KPI03_pico_kw  \
# 0  125.89  126.85  127.37  25.1  ...          NaN        NaN            NaN
# 1  123.82  124.58  123.91  17.4  ...          NaN        NaN            NaN
# 2  130.14  130.55  129.53   7.5  ...          NaN        NaN            NaN
# 3  132.14  131.50  132.07  30.0  ...          NaN        NaN            NaN
# 4  127.88  128.72  128.50   5.3  ...          NaN        NaN            NaN
#
#    KPI03_hora_pico  KPI05_CO2_tCO2e  KPI08_LF  KPI09_f4_pct  \
# 0              NaN              NaN       NaN           NaN
# 1              NaN              NaN       NaN           NaN
# 2              NaN              NaN       NaN           NaN
# 3              NaN              NaN       NaN           NaN
# 4              NaN              NaN       NaN           NaN
#
#    KPI10_desbalance_pct  KPI11_fp  KPI12_thd_v_pct
# 0                   NaN       NaN              NaN
# 1                   NaN       NaN              NaN
# 2                   NaN       NaN              NaN
# 3                   NaN       NaN              NaN
# 4                   NaN       NaN              NaN
#
# [5 rows x 70 columns]

# %% [markdown]
# ## Bloque 2 — Conversión de tipos y selección de columnas

# %%
COLS = ['time_index_colombia', 'entity_id', 'activepower', 'totalpowerfactor',
        'relativethdvoltage', 'activeenergyimport', 'v1', 'v2', 'v3']
df = df[COLS].copy()

df['time_index_colombia'] = pd.to_datetime(df['time_index_colombia'], utc=False, format='%d/%m/%Y %H:%M')
df['entity_id'] = df['entity_id'].astype('category')

num_cols = ['activepower', 'totalpowerfactor', 'relativethdvoltage', 'activeenergyimport', 'v1', 'v2', 'v3']
for col in num_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

print(df.dtypes)
# Out:
# time_index_colombia    datetime64[ns]
# entity_id                    category
# activepower                   float64
# totalpowerfactor              float64
# relativethdvoltage            float64
# activeenergyimport            float64
# v1                            float64
# v2                            float64
# v3                            float64
# dtype: object

# %% [markdown]
# ## Bloque 3 — Descripción estadística
#
# ### 3.1 Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640061 entries, 0 to 640060
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   time_index_colombia  639131 non-null  datetime64[ns]
#  1   entity_id            640061 non-null  category
#  2   activepower          639077 non-null  float64
#  3   totalpowerfactor     639077 non-null  float64
#  4   relativethdvoltage   639077 non-null  float64
#  5   activeenergyimport   639077 non-null  float64
#  6   v1                   639077 non-null  float64
#  7   v2                   639077 non-null  float64
#  8   v3                   639077 non-null  float64
# dtypes: category(1), datetime64[ns](1), float64(7)
# memory usage: 39.7 MB

# %%
df.describe(include='all')
# Out:
#                   time_index_colombia              entity_id    activepower  \
# count                          639131                 640061  639077.000000
# unique                            NaN                     16            NaN
# top                               NaN  SmartMeter_SM_B9_SFA1            NaN
# freq                              NaN                  40791            NaN
# mean    2026-03-03 07:36:29.147422976                    NaN   18269.636563
# min               2026-02-10 00:01:09                    NaN       0.000000
# 25%               2026-02-28 02:44:50                    NaN    4113.400000
# 50%               2026-03-05 16:25:45                    NaN   12197.800000
# 75%               2026-03-09 05:13:08                    NaN   28359.300000
# max               2026-03-12 17:47:06                    NaN  125934.200000
# std                               NaN                    NaN   18146.673106
#
#         totalpowerfactor  relativethdvoltage  activeenergyimport  \
# count      639077.000000       639077.000000        6.390770e+05
# unique               NaN                 NaN                 NaN
# top                  NaN                 NaN                 NaN
# freq                 NaN                 NaN                 NaN
# mean            0.890639            2.616911        4.890299e+07
# min            -0.810000            0.661000        5.490000e+01
# 25%             0.870000            1.494000        1.501426e+07
# 50%             0.960000            1.814000        4.152870e+07
# 75%             0.990000            2.237000        8.421743e+07
# max             1.000000           15.866000        1.000000e+08
# std             0.205970            2.985505        3.342394e+07
#
#                    v1             v2             v3
# count   639077.000000  639077.000000  639077.000000
# unique            NaN            NaN            NaN
# top               NaN            NaN            NaN
# freq              NaN            NaN            NaN
# mean       125.045505     126.897166     126.280797
# min        107.100000     119.570000     114.570000
# 25%        123.270000     124.100000     124.120000
# 50%        125.310000     126.020000     125.910000
# 75%        127.300000     128.460000     127.990000
# max        137.150000     144.850000     137.140000
# std          4.387026       4.128506       2.897210

# %% [markdown]
# ### 3.2 — Distribución temporal y por entidad
#
# **Celda A — Registros por día**

# %%
by_day = df.groupby(df['time_index_colombia'].dt.date).size()
fig, ax = plt.subplots()
ax.plot(by_day.index, by_day.values)
ax.set_xlabel('Fecha')
ax.set_ylabel('Conteo')
ax.set_title('Registros por día')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Celda B — Registros por hora del día**

# %%
by_hour = df.groupby(df['time_index_colombia'].dt.hour).size()
fig, ax = plt.subplots()
ax.bar(by_hour.index, by_hour.values)
ax.set_xlabel('Hora')
ax.set_ylabel('Conteo')
ax.set_title('Registros por hora del día')
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
plt.tight_layout()
plt.show()

# %% [markdown]
# **Celda C — Registros por entity_id**

# %%
by_entity = df['entity_id'].value_counts()
fig, ax = plt.subplots(figsize=(10, max(4, len(by_entity) * 0.3)))
ax.barh(by_entity.index.astype(str), by_entity.values)
ax.set_xlabel('Conteo')
ax.set_title('Registros por entity_id')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3.3 — Distribuciones de variables numéricas

# %% [markdown]
# **activepower — histograma**

# %%
fig, ax = plt.subplots()
ax.hist(df['activepower'].dropna(), bins=100)
ax.set_xlabel('activepower')
ax.set_ylabel('Frecuencia')
ax.set_title('Histograma — activepower')
plt.tight_layout()
plt.show()

# %% [markdown]
# **activepower — boxplot**

# %%
fig, ax = plt.subplots()
ax.boxplot(df['activepower'].dropna(), vert=False)
ax.set_xlabel('activepower')
ax.set_title('Boxplot — activepower')
plt.tight_layout()
plt.show()

# %% [markdown]
# **totalpowerfactor — histograma**

# %%
fig, ax = plt.subplots()
ax.hist(df['totalpowerfactor'].dropna(), bins=100)
ax.set_xlabel('totalpowerfactor')
ax.set_ylabel('Frecuencia')
ax.set_title('Histograma — totalpowerfactor')
plt.tight_layout()
plt.show()

# %% [markdown]
# **totalpowerfactor — boxplot**

# %%
fig, ax = plt.subplots()
ax.boxplot(df['totalpowerfactor'].dropna(), vert=False)
ax.set_xlabel('totalpowerfactor')
ax.set_title('Boxplot — totalpowerfactor')
plt.tight_layout()
plt.show()

# %% [markdown]
# **relativehdvoltage — histograma**

# %%
fig, ax = plt.subplots()
ax.hist(df['relativethdvoltage'].dropna(), bins=100)
ax.set_xlabel('relativethdvoltage')
ax.set_ylabel('Frecuencia')
ax.set_title('Histograma — relativethdvoltage')
plt.tight_layout()
plt.show()

# %% [markdown]
# **relativehdvoltage — boxplot**

# %%
fig, ax = plt.subplots()
ax.boxplot(df['relativethdvoltage'].dropna(), vert=False)
ax.set_xlabel('relativethdvoltage')
ax.set_title('Boxplot — relativethdvoltage')
plt.tight_layout()
plt.show()

# %% [markdown]
# **activeenergyimport — histograma**

# %%
fig, ax = plt.subplots()
ax.hist(df['activeenergyimport'].dropna(), bins=100)
ax.set_xlabel('activeenergyimport')
ax.set_ylabel('Frecuencia')
ax.set_title('Histograma — activeenergyimport')
plt.tight_layout()
plt.show()

# %% [markdown]
# **activeenergyimport — boxplot**

# %%
fig, ax = plt.subplots()
ax.boxplot(df['activeenergyimport'].dropna(), vert=False)
ax.set_xlabel('activeenergyimport')
ax.set_title('Boxplot — activeenergyimport')
plt.tight_layout()
plt.show()

# %% [markdown]
# **v1 — histograma**

# %%
fig, ax = plt.subplots()
ax.hist(df['v1'].dropna(), bins=100)
ax.set_xlabel('v1')
ax.set_ylabel('Frecuencia')
ax.set_title('Histograma — v1')
plt.tight_layout()
plt.show()

# %% [markdown]
# **v1 — boxplot**

# %%
fig, ax = plt.subplots()
ax.boxplot(df['v1'].dropna(), vert=False)
ax.set_xlabel('v1')
ax.set_title('Boxplot — v1')
plt.tight_layout()
plt.show()

# %% [markdown]
# **v2 — histograma**

# %%
fig, ax = plt.subplots()
ax.hist(df['v2'].dropna(), bins=100)
ax.set_xlabel('v2')
ax.set_ylabel('Frecuencia')
ax.set_title('Histograma — v2')
plt.tight_layout()
plt.show()

# %% [markdown]
# **v2 — boxplot**

# %%
fig, ax = plt.subplots()
ax.boxplot(df['v2'].dropna(), vert=False)
ax.set_xlabel('v2')
ax.set_title('Boxplot — v2')
plt.tight_layout()
plt.show()

# %% [markdown]
# **v3 — histograma**

# %%
fig, ax = plt.subplots()
ax.hist(df['v3'].dropna(), bins=100)
ax.set_xlabel('v3')
ax.set_ylabel('Frecuencia')
ax.set_title('Histograma — v3')
plt.tight_layout()
plt.show()

# %% [markdown]
# **v3 — boxplot**

# %%
fig, ax = plt.subplots()
ax.boxplot(df['v3'].dropna(), vert=False)
ax.set_xlabel('v3')
ax.set_title('Boxplot — v3')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Bloque 4 — Limpieza de atípicos
#
# ### 4.1 — Conversión a numéricos

# %% [markdown]
# ### 4.2 — Validación de rangos físicos

# %%
print('NaNs antes:')
print(df[num_cols].isna().sum())

RANGES = {
    'activeenergyimport': (0, 500_000_000),
    'relativethdvoltage':  (0, 100),
    'totalpowerfactor':   (-1.0, 1.0),
    'activepower':        (0, 2_000_000),
    ##Estos rangos de tensión se establecen como referencia, 
    ##pero no se aplican para eliminar outliers, ya que podrían ser causados por eventos reales en la red eléctrica.
    #'v1':                 (114.45, 133.53),
    #'v2':                 (114.45, 133.53),
    #'v3':                 (114.45, 133.53),
}

for col, (lo, hi) in RANGES.items():
    df[col] = df[col].where(df[col].between(lo, hi))

print('NaNs después:')
print(df[num_cols].isna().sum())
# Out:
# NaNs antes:
# activepower           984
# totalpowerfactor      984
# relativethdvoltage    984
# activeenergyimport    984
# v1                    984
# v2                    984
# v3                    984
# dtype: int64
# NaNs después:
# activepower             984
# totalpowerfactor        984
# relativethdvoltage      984
# activeenergyimport      984
# v1                    48164
# v2                    40969
# v3                     8659
# dtype: int64

# %% [markdown]
# ### 4.3 — Eliminación de filas sin información esencial

# %%
before = len(df)
df.dropna(inplace=True)
print(f'Filas eliminadas: {before - len(df)}  — shape resultante: {df.shape}')
# Out:
# Filas eliminadas: 49890  — shape resultante: (590171, 9)

# %%
by_entity = df['entity_id'].value_counts()
fig, ax = plt.subplots(figsize=(10, max(4, len(by_entity) * 0.3)))
ax.barh(by_entity.index.astype(str), by_entity.values)
ax.set_xlabel('Conteo')
ax.set_title('Registros por entity_id')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Bloque 5 — Resample configurable

# %%
FREQ = '60min'

df_resampled = (
    df.set_index('time_index_colombia')
    .groupby('entity_id', observed=True)
    .resample(FREQ)
    .agg({
        'activepower':        'mean',
        'totalpowerfactor':   'mean',
        'relativethdvoltage':  'mean',
        'v1':                 'mean',
        'v2':                 'mean',
        'v3':                 'mean',
        'activeenergyimport': 'mean',
    })
    .reset_index()
)

print(df_resampled.shape)
# Out:
# (10575, 9)

# %%
before = len(df_resampled)
df_resampled.dropna(inplace=True)
print(f'Filas eliminadas: {before - len(df_resampled)}  — shape resultante: {df_resampled.shape}')
# Out:
# Filas eliminadas: 38  — shape resultante: (10537, 9)

# %% [markdown]
# ## Bloque 6 — Exportación

# %%
csv_path     = 'etsmartmeter_clean.csv'
parquet_path = 'etsmartmeter_clean.parquet'

df_resampled.to_csv(csv_path, index=False)
df_resampled.to_parquet(parquet_path, engine='pyarrow', index=False)

print(f'CSV guardado en:     {csv_path}  — shape: {df_resampled.shape}')
print(f'Parquet guardado en: {parquet_path}  — shape: {df_resampled.shape}')
# Out:
# CSV guardado en:     etsmartmeter_clean.csv  — shape: (10537, 9)
# Parquet guardado en: etsmartmeter_clean.parquet  — shape: (10537, 9)
